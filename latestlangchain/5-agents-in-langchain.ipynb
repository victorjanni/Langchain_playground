# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool
from langgraph.prebuilt import create_react_agent

import requests


@tool
def get_weather_data(city: str) -> str:
    """Get current weather"""

    url = f"https://api.weatherstack.com/current?access_key=keepyourapihere&query={city}"

    return requests.get(url).text


search_tool = DuckDuckGoSearchRun()

model = init_chat_model(
    "groq:qwen/qwen3-32b"
)

agent = create_react_agent(
    model=model,
    tools=[
        search_tool,
        get_weather_data
    ]
)

response = agent.invoke(
    {
        "messages": [
            (
                "user",
                "Find the capital of Andhra pradesh and current weather"
            )
        ]
    }
)

print(
    response["messages"][-1].content
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10012\1158292650.py:24: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(
# The capital of Andhra Pradesh is **Amaravati**, which was officially designated as the permanent capital in 2026 after legislative approval.
#
# Here’s the current weather in **Amaravati**:
# - **Temperature**: 39°C
# - **Condition**: Patchy rain nearby
# - **Humidity**: 24%
# - **Wind Speed**: 26 km/h
# - **UV Index**: 0 (Low)
#
# Let me know if you need further details! 🌦️
